# %%
print("Hello, World!")
# Out:
# The kernel failed to start as the Python Environment 'Python 3.12.13' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
